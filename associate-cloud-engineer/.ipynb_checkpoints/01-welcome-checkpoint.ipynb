# %% [markdown]
# <h1 style='font-size:40px'> Welcome </h1>
# <div>
#     <ul style='font-size:20px'>
#         <li>
#         </li>
#     </ul>
# </div>

# %% [markdown]
# <h2 style='font-size:30px'> The Big Picture: GCP's Global Infrastructure (Regions, Zones, Edge Locations)</h2>
# <div>
#     <ul style='font-size:20px'>
#         <li>
#             Apresentação de conceitos de hierarquia dos pontos de presença do Google Cloud.
#         </li>
#         <li>
#             De maneira geral, são bem parecidos com a AWS (Regions, Zones, Edge Locations).
#         </li>
#         <li>
#             Edge locations seriam pontos de presença da rede interna do GCP voltados a manter proximidade com os consumidores das nossas aplicações, reduzindo a latência do seu uso.
#         </li>
#     </ul>
# </div>

# %% [markdown]
# <h2 style='font-size:30px'> A Guided Tour of the Google Cloud Console</h2>
# <div>
#     <ul style='font-size:20px'>
#         <li>
#             Aula em que o instrutor apresenta uma visão geral sobre a interface do GCP.
#         </li>
#         <li>
#             No Google Cloud, temos um nível de abstração conhecido como Projects. Eles funcionariam como pastas onde podemos implantar dferentes recursos. Poderíamos usar cada um deles como um ambiente, por exemplo (dev, hom, prod).
#         </li>
#     </ul>
# </div>

# %% [markdown]
# <h3 style='font-size:30px;font-style:italic'>
#     Disponibilidade de Serviços
# </h3>
# <div>
#     <ul style='font-size:20px'>
#         <li>
#             Antes de implantarmos qualquer arquitetura, é recomendável avaliarmos se os serviços que queremos usar estão disponíveis na região de deployment.
#         </li>
#         <li>
#             Para isso, o GCP fornece uma <a href='https://cloud.google.com/about/locations'>página</a> onde podemos averiguar isso.
#         </li>
#      </ul>
# </div>

# %% [markdown]
# <h3 style='font-size:30px;font-style:italic'>
#     Interação com GCP
# </h3>
# <div>
#     <ul style='font-size:20px'>
#         <li>
#             AAssim como a AWS, o GCP fornece não apenas a GUI, como também uma CLI e SDK's para podermos interagir com nossos recursos da maneira que for mais cômoda para nós.
#         </li>
#      </ul>
# </div>

# %% [markdown]
# <h3 style='font-size:30px;font-style:italic'>
#     Cloud Shell
# </h3>
# <div>
#     <ul style='font-size:20px'>
#         <li>
#             Assim como na AWS, o GCP oferece em seu console um terminal onde podemos criar arquiteturas de diretórios e salvar arquivos.
#         </li>
#      </ul>
# </div>

# %% [markdown]
# <figure>
#     <center style='font-size:20px;margin-top:20px'>
#         <img src='img/01-cloud-shell.png'>
#         <figcaption style='font-size:15px'>
#         </figcaption>
#     </center>
# </figure>

# %%
! git add .
! git commit -am 'Aula 12' 
! git push
# Out:
# [master 2b9262f] Aula 9
#  4 files changed, 246 insertions(+)
#  create mode 100644 associate-cloud-engineer/.ipynb_checkpoints/01-welcome-checkpoint.ipynb
#  create mode 100644 associate-cloud-engineer/01-welcome.ipynb
#  create mode 100644 associate-cloud-engineer/contents/.ipynb_checkpoints/course-material-checkpoint.pdf
#  create mode 100644 associate-cloud-engineer/contents/course-material.pdf
# Enumerating objects: 9, done.
# Counting objects: 100% (9/9), done.
# Delta compression using up to 24 threads
# Compressing objects: 100% (8/8), done.
# Writing objects: 100% (8/8), 433.83 KiB | 27.11 MiB/s, done.
# Total 8 (delta 0), reused 0 (delta 0), pack-reused 0
# To https://github.com/felipesveiga/gcp.git
#    4b37ba0..2b9262f  master -> master

# %% [markdown]
# <p style='color:red'> Vi Aula 9 a 11; Aula 12
